# %% [markdown]
# # Test attempt with 10 products

# %%
# Imports
from sentence_transformers import SentenceTransformer
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from huggingface_hub import login
login(token=os.getenv("HF_ACCESS_TOKEN"))

# %%
"""
Target Queries:
pet - 2
mother - 2
father - 3
boyfriend - 2
diwali - 2
edible - 2
"""
# Out:
# '\nTarget Queries:\npet - 2\nmother - 2\nfather - 3\nboyfriend - 2\ndiwali - 2\nedible - 2\n'

# %%
products = [
    """Title: Personalised Pet Birthday Wish Acrylic Plaque, Description: Capture the beauty of life with our unique keepsakes. Our beautiful keepsakes preserve your memories, pictures, and important details in pretty displays. The keepsakes are made of high-quality acrylic that is shatter-resistant and offers a nice frosted look when printed. With ample room for personalization, these beauties make a perfect and artful gift for that special someone!

utility : best to gift to pet lover, dog birthday, new pet homecoming etc.


Dimensions: 15 x 15 cm (6x6)
Material: Plexiglass Acrylic 8mm
Product Weight: 150 gm
Package Weight: 600 gm
Number of Items: 1""",
     
    """Title: Eze Magic - 18ML Men Perfume, Description: Eze Magic – 18 ML Men Perfume is a compact, travel‑friendly fragrance that blends fresh citrus, aromatic spices, and warm musk for a crisp, invigorating scent. Perfect for everyday use, it offers lasting appeal in a small bottle—ideal for office, gym, or on-the-go touch-ups—delivering confidence wherever you roam.

FRAGRANCE NOTES:

Top Notes :Cinnamon, Pink Pepper, Chestnut
Middle Notes :Lavender, Amber, Tobacco
Base Notes : Leather, Oud, Cedarwood
PERFUME CARE:
The key is to keep it away from light and heat – so a bathroom, or a sunny dressing table, is NOT the place for your fragrance: higher temperatures affect the top notes of a fragrance, making it musty, or more sour. If you have a dark cupboard to store perfume in, or a drawer, that’s perfect.

Ideally, keep it in the box, or – if you’re using a drawer – wrap bottles in a scarf, or even plastic, unglamorous as that is. Be aware that perfume that’s never been opened and kept in a dark place can last more than 40 years!

Product Weight: 18ml
Number of Items: 1
Expiration Date: 36 Months from Manufacturing Date""",

"""
Title: Irresistible Diwali Hamper, Description: One Box of Motichoor Laddu- 1 Kg
Mixed Dry Fruits (Almonds & Cashew Nuts)- 500 gms each
Dry Fruits packed in Red Net & Tied with White Raffia

Number of Items: 4
""",

"""Title: Personalised Happy Diwali - Divine Diwali Choco Bar, Description: Celebrate the Festival of Lights with our Personalized Happy Diwali Choco Bars! These delightful chocolate bars are perfect for gifting or as festive treats. Customize them with a heartfelt message. Ideal for sharing with family and friends, these choco bars add a sweet touch to your celebrations. Brighten up this Diwali with a unique and memorable gift! Order your personalized choco bars today and spread the joy of the season!. Wrapped and presented in a premium quality glossy paper, Bournville / Cadbury Chocolate that comes in two sizes 80 gm and 260 gms (130 gm x 2) respectively.Personalised choco bars are foil wrapped then finished with a full colour, personalised wrapper for maximum impact and presentation.


Ingredients:

 

Fabric cover - Material Available: Polyester canvas and velvet
Fabric filling: High-Quality Conjugated Fiber Filler
Dimension: 30 x 30 cm (12x12)
Stitching - Envelop Backing | Outline Seam Stitch | Interlocked from inside.
Filler instruction - Cushion Filler comes Vacuum Packed, hence is flat and compressed. Please cut the cover and re-fluff lightly with your hands. The cushion will soon regain its shape.
Care instruction - Machine Washable| Preferably Hand wash normally in cold water | Tumble dry on low | Warm Iron as needed | Do not Bleach or Soak | Wash Cover Only, not the filler.

Material: Polyester Canvas & Poly Velvet
Product Weight: 250 gm
Package Weight: 260 gm
Number of Items: 1 cushion cover with free filler / insert ( not sold separately)
""",

"""
Title: Personalised Diagonal Metal Initial Cufflinks, Description: Make a statement with these sleek metal initial cufflinks that let your personality shine through! Perfect for dressing up any formal occasion, these personalized accessories add a touch of sophistication with a dash of fun. Whether you're heading to a wedding, business meeting, or special event, customize them with your favorite initial to create a truly one-of-a-kind piece. Polished metal construction ensures durability and timeless style. Slip them on and watch heads turn!

Size: One size

Water resistance: Can withstand normal splashes of water

Hypoallergenic: Gentle on your sensitive skin

Utility: Built for durability and meaning, this metal  initial cufflinks are a bold statement of strength, identity, and personal pride.

Material: High-grade brass
Product weight: 20 gram
Number of Items: 1
""",

"""
Title: Pet Watercolor Painting From Photo, Description: Authentic 100% Handmade Pet Watercolor Painting from Photo made by the professional portrait artists. Each piece is unique & made with even the utmost attention to minute details. Do you love playing with colors and splashing water on others? Our artists splash watercolors on your best pictures and convert them into a masterpiece, you never thought of!


Material: watercolors
Product Weight: 400 gm
Number of Items: 1
"""
]

# %%
model = SentenceTransformer("google/embeddinggemma-300m")

document_embeddings = model.encode_document(products)
print(query_embeddings.shape, document_embeddings.shape)
# Out:
# No sentence-transformers model found with name google/embeddinggemma-300m. Creating a new one with mean pooling.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:402, in hf_raise_for_status(response, endpoint_name)
#     401 try:
# --> 402     response.raise_for_status()
#     403 except HTTPError as e:
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/google/embeddinggemma-300m/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/transformers/utils/hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     477 if len(full_filenames) == 1:
#     478     # This is slightly better for only 1 file
# --> 479     hf_hub_download(
#     480         path_or_repo_id,
#     481         filenames[0],
#     482         subfolder=None if len(subfolder) == 0 else subfolder,
#     483         repo_type=repo_type,
#     484         revision=revision,
#     485         cache_dir=cache_dir,
#     486         user_agent=user_agent,
#     487         force_download=force_download,
#     488         proxies=proxies,
#     489         resume_download=resume_download,
#     490         token=token,
#     491         local_files_only=local_files_only,
#     492     )
#     493 else:
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1114, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1113     # Otherwise, raise appropriate error
# -> 1114     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1116 # From now on, etag, commit_hash, url and size are not None.
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1655, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1650 elif isinstance(head_call_error, (RepositoryNotFoundError, GatedRepoError)) or (
#    1651     isinstance(head_call_error, HfHubHTTPError) and head_call_error.response.status_code == 401
#    1652 ):
#    1653     # Repo not found or gated => let's raise the actual error
#    1654     # Unauthorized => likely a token issue => let's raise the actual error
# -> 1655     raise head_call_error
#    1656 else:
#    1657     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1543, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1542 try:
# -> 1543     metadata = get_hf_file_metadata(
#    1544         url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#    1545     )
#    1546 except EntryNotFoundError as http_error:
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1460, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1459 # Retrieve metadata
# -> 1460 r = _request_wrapper(
#    1461     method="HEAD",
#    1462     url=url,
#    1463     headers=hf_headers,
#    1464     allow_redirects=False,
#    1465     follow_relative_redirects=True,
#    1466     proxies=proxies,
#    1467     timeout=timeout,
#    1468 )
#    1469 hf_raise_for_status(r)
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:283, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     282 if follow_relative_redirects:
# --> 283     response = _request_wrapper(
#     284         method=method,
#     285         url=url,
#     286         follow_relative_redirects=False,
#     287         **params,
#     288     )
#     290     # If redirection, we redirect only relative paths.
#     291     # This is useful in case of a renamed repository.
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:307, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     306 response = http_backoff(method=method, url=url, **params)
# --> 307 hf_raise_for_status(response)
#     308 return response
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:419, in hf_raise_for_status(response, endpoint_name)
#     416     message = (
#     417         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     418     )
# --> 419     raise _format(GatedRepoError, message, response) from e
#     421 elif error_message == "Access to this resource is disabled.":
#
# GatedRepoError: 401 Client Error. (Request ID: Root=1-693ab75d-482c6a975f51ca753117dd45;edd5e7ca-67ea-4e51-a40a-2510af6010af)
#
# Cannot access gated repo for url https://huggingface.co/google/embeddinggemma-300m/resolve/main/config.json.
# Access to model google/embeddinggemma-300m is restricted. You must have access to it and be authenticated to access it. Please log in.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model = SentenceTransformer("google/embeddinggemma-300m")
#       3 document_embeddings = model.encode_document(products)
#       4 print(query_embeddings.shape, document_embeddings.shape)
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:339, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     327         modules, self.module_kwargs = self._load_sbert_model(
#     328             model_name_or_path,
#     329             token=token,
#    (...)    336             config_kwargs=config_kwargs,
#     337         )
#     338     else:
# --> 339         modules = self._load_auto_model(
#     340             model_name_or_path,
#     341             token=token,
#     342             cache_folder=cache_folder,
#     343             revision=revision,
#     344             trust_remote_code=trust_remote_code,
#     345             local_files_only=local_files_only,
#     346             model_kwargs=model_kwargs,
#     347             tokenizer_kwargs=tokenizer_kwargs,
#     348             config_kwargs=config_kwargs,
#     349             has_modules=has_modules,
#     350         )
#     352 if modules is not None and not isinstance(modules, OrderedDict):
#     353     modules = OrderedDict([(str(idx), module) for idx, module in enumerate(modules)])
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:2112, in SentenceTransformer._load_auto_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs, has_modules)
#    2109 tokenizer_kwargs = shared_kwargs if tokenizer_kwargs is None else {**shared_kwargs, **tokenizer_kwargs}
#    2110 config_kwargs = shared_kwargs if config_kwargs is None else {**shared_kwargs, **config_kwargs}
# -> 2112 transformer_model = Transformer(
#    2113     model_name_or_path,
#    2114     cache_dir=cache_folder,
#    2115     model_args=model_kwargs,
#    2116     tokenizer_args=tokenizer_kwargs,
#    2117     config_args=config_kwargs,
#    2118     backend=self.backend,
#    2119 )
#    2120 pooling_model = Pooling(transformer_model.get_word_embedding_dimension(), "mean")
#    2121 if not local_files_only:
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/sentence_transformers/models/Transformer.py:87, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#      84 if config_args is None:
#      85     config_args = {}
# ---> 87 config, is_peft_model = self._load_config(model_name_or_path, cache_dir, backend, config_args)
#      88 self._load_model(model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#      90 # Get the signature of the auto_model's forward method to pass only the expected arguments from `features`,
#      91 # plus some common values like "input_ids", "attention_mask", etc.
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/sentence_transformers/models/Transformer.py:162, in Transformer._load_config(self, model_name_or_path, cache_dir, backend, config_args)
#     158     from peft import PeftConfig
#     160     return PeftConfig.from_pretrained(model_name_or_path, **config_args, cache_dir=cache_dir), True
# --> 162 return AutoConfig.from_pretrained(model_name_or_path, **config_args, cache_dir=cache_dir), False
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/transformers/models/auto/configuration_auto.py:1332, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1329 trust_remote_code = kwargs.pop("trust_remote_code", None)
#    1330 code_revision = kwargs.pop("code_revision", None)
# -> 1332 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1333 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#    1334 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/transformers/configuration_utils.py:662, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     660 original_kwargs = copy.deepcopy(kwargs)
#     661 # Get config dict associated with the base config file
# --> 662 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     663 if config_dict is None:
#     664     return {}, kwargs
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/transformers/configuration_utils.py:721, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     717 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     719 try:
#     720     # Load from local folder or from cache or download from model Hub and cache
# --> 721     resolved_config_file = cached_file(
#     722         pretrained_model_name_or_path,
#     723         configuration_file,
#     724         cache_dir=cache_dir,
#     725         force_download=force_download,
#     726         proxies=proxies,
#     727         resume_download=resume_download,
#     728         local_files_only=local_files_only,
#     729         token=token,
#     730         user_agent=user_agent,
#     731         revision=revision,
#     732         subfolder=subfolder,
#     733         _commit_hash=commit_hash,
#     734     )
#     735     if resolved_config_file is None:
#     736         return None, kwargs
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/transformers/utils/hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)    320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File ~/Desktop/verve/chatbot/venv/lib/python3.12/site-packages/transformers/utils/hub.py:543, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     541     if not _raise_exceptions_for_gated_repo:
#     542         return None
# --> 543     raise OSError(
#     544         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     545         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     546     ) from e
#     547 elif isinstance(e, LocalEntryNotFoundError):
#     548     if not _raise_exceptions_for_connection_errors:
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/google/embeddinggemma-300m.
# 401 Client Error. (Request ID: Root=1-693ab75d-482c6a975f51ca753117dd45;edd5e7ca-67ea-4e51-a40a-2510af6010af)
#
# Cannot access gated repo for url https://huggingface.co/google/embeddinggemma-300m/resolve/main/config.json.
# Access to model google/embeddinggemma-300m is restricted. You must have access to it and be authenticated to access it. Please log in.

# %%
query = "Which planet is known as the Red Planet?"
query_embeddings = model.encode_query(query)

# %% [markdown]
# # OLD CODE

# %%
embeddings = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001"
)

# Create Document objects from products with metadata
documents = []
for idx, product in enumerate(products):
    doc = Document(
        page_content=product,  # The product text itself
        metadata={"product_id": idx}  # Associate array index as product_id
    )
    documents.append(doc)

# Create ChromaDB vector store with the documents
persist_directory = "./chroma_db"
collection_name = "products_collection"

try:
    vectorstore = Chroma.from_documents(
        documents=documents,
        embedding=embeddings,
        persist_directory=persist_directory,
        collection_name=collection_name
    )
    print(f"Created ChromaDB vector store with {len(documents)} products!")
    
except Exception as e:
    print(f"Error setting up ChromaDB: {str(e)}")
# Out:
# Created ChromaDB vector store with 9 products!

# %%
# Create retriever
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 1}  # K is the amount of products to return
)

def retriever_tool(query: str) -> str:
    """
    This tool searches and returns relevant products based on the query.
    """
    docs = retriever.invoke(query)

    if not docs:
        return "I found no relevant products."
    
    results = []
    for i, doc in enumerate(docs):
        product_id = doc.metadata.get('product_id', 'Unknown')
        results.append(f"Product {i+1} (ID: {product_id}):\n{doc.page_content}")
    
    return "\n\n".join(results)

# %%
retriever_tool("I am hungry and want to eat something chocolaty.")
# Out:
# 'Product 1 (ID: 3):\nTitle: Personalised Happy Diwali - Divine Diwali Choco Bar, Description: Celebrate the Festival of Lights with our Personalized Happy Diwali Choco Bars! These delightful chocolate bars are perfect for gifting or as festive treats. Customize them with a heartfelt message. Ideal for sharing with family and friends, these choco bars add a sweet touch to your celebrations. Brighten up this Diwali with a unique and memorable gift! Order your personalized choco bars today and spread the joy of the season!. Wrapped and presented in a premium quality glossy paper, Bournville / Cadbury Chocolate that comes in two sizes 80 gm and 260 gms (130 gm x 2) respectively.Personalised choco bars are foil wrapped then finished with a full colour, personalised wrapper for maximum impact and presentation.\n\n\nIngredients:\n\n\n\nBournville Ingredients: Sugar, Cocoa Solids (45%#), Cocoa Butter (25%#), Milk Solids, Emulsifiers (442, 476) Contains Added Flavour (Natural And Nature Identical Flavouring Substances) Allergen Information: Contains Milk, Manufactured on Equipment That Also Processes Products Containing Tree Nuts..\n\nCadbury Dairy Milk Ingredients: Sugar, Milk Solids (23%*), Cocoa Butter, Cocoa Solids, Emulsifiers (442, 476), Flavours (Natural, Nature Identical And Artificial (Vanilla) Flavouring Substances). Allergen Information: Contains Milk. May Contain Tree Nuts, Wheat, Barley And Soy.\n\nCare Instructions: Store the Chocolate in the refrigerator before consuming.  Please consume before the expiry date.\n\nutility : perfect to gift to family , friend & loved once on diwali \n\nMaterial:  Wrap Glossy Paper 180 gsm\nDimensions: Bournville 3.5 x 22.1 x 52.1 cm/ Cadbury Dairy Milk \u200e3.5 x 22.1 x 52.1 cm\nProduct Weight: 100 gm / 280 gm\nPackaged Weight 200 gm / 400 gm\nNumber of Items:  Bournville 1 (80 gm) / Cadbury Dairy Milk - 2 pcs (130 gm each)\nExpiry Date : Best  before 12 month from packaging'
