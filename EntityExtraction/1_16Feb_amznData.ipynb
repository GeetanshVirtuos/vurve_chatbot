# %%
import pandas as pd

df_examples = pd.read_parquet('./shopping_queries_dataset/shopping_queries_dataset_examples.parquet')
df_products = pd.read_parquet('./shopping_queries_dataset/shopping_queries_dataset_products.parquet')
df_sources = pd.read_csv("./shopping_queries_dataset/shopping_queries_dataset_sources.csv")

# %%
df_small = df_examples[df_examples["small_version"] == 1]
df_small.head()
# Out:
#     example_id                         query  query_id  product_id  \
# 16          16  !awnmower tires without rims         1  B075SCHMPY
# 17          17  !awnmower tires without rims         1  B08L3B9B9P
# 18          18  !awnmower tires without rims         1  B082K7V2GZ
# 19          19  !awnmower tires without rims         1  B07P4CF3DP
# 20          20  !awnmower tires without rims         1  B07C1WZG12
#
#    product_locale esci_label  small_version  large_version  split
# 16             us          I              1              1  train
# 17             us          E              1              1  train
# 18             us          I              1              1  train
# 19             us          S              1              1  train
# 20             us          E              1              1  train

# %%
pd.set_option('display.max_rows', None)
df_small[['query_id', 'query']][50000:60000]
